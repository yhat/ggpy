# %%
# %matplotlib inline
from ggplot import *
import pandas as pd

# %%
meat = pd.melt(meat, id_vars="date")

# %%
ggplot(meat, aes(x='date', y='value', color='variable')) + \
    geom_step()
# Out:
# <ggplot: (290362721)>
