# %%
# %matplotlib inline
from ggplot import *

# %%
ggplot(mpg, aes(x='cty')) + \
    geom_histogram() + \
    xlab("City MPG (Miles per Gallon)") + \
    ylab("# of Obs")
# Out:
# <ggplot: (274955645)>
