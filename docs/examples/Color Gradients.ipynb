# %%
# %matplotlib inline
from ggplot import *

# %%
ggplot(diamonds, aes(x='carat', y='price', color='depth')) + \
    geom_point() + \
    scale_color_gradient(low="white", high="royalblue")
# Out:
# <ggplot: (274929741)>
