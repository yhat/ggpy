# %%
# %matplotlib inline
from ggplot import *
import pandas as pd

# %%
mpg = pd.melt(mpg[['hwy', 'cty']])

# %%
ggplot(mpg, aes(x='value', color='variable')) + \
    geom_density()
# Out:
# <ggplot: (285111193)>
