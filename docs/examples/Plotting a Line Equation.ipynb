# %%
# %matplotlib inline
from ggplot import *

# %%
ggplot(mpg, aes(x='cty', y='hwy')) + \
    geom_point() + \
    geom_abline(slope=1, intercept=5, color='steelblue')
# Out:
# <ggplot: (285097725)>
