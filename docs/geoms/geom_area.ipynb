# %%
from ggplot import *
# %matplotlib inline

# %%
ggplot(meat, aes(x='date', ymin='beef - 1000', ymax='beef + 1000')) + geom_area()
# Out:
# <ggplot: (287649089)>

# %%
ggplot(meat, aes(x='date', ymin='beef*0.9', ymax='beef*1.1')) + \
    geom_area()
# Out:
# <ggplot: (288514641)>

# %%
ggplot(meat, aes(x='date', y='beef', ymin='beef*0.9', ymax='beef*1.1')) + \
    geom_area() + \
    geom_point()
# Out:
# <ggplot: (288619501)>
