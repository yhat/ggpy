# %%
# %matplotlib inline
from ggplot import *

# %% [markdown]
# ### Look and Feel - Themes
# Like everything else, you can apply a *theme* layer to your ggplots in order to make them look different. ggplot comes with 3 built in themes:
#
# - `theme_gray` (default)
# - `theme_bw`
# - `theme_xkcd`
# - `theme_538`
#
# See examples below!

# %%
ggplot(diamonds, aes(x='price')) + geom_histogram()
# Out:
# <ggplot: (284434013)>

# %%
ggplot(diamonds, aes(x='price')) + geom_histogram() + theme_gray()
# Out:
# <ggplot: (285822353)>

# %%
ggplot(diamonds, aes(x='price')) + geom_histogram() + theme_bw()
# Out:
# <ggplot: (285255953)>

# %%
ggplot(diamonds, aes(x='price')) + geom_histogram() + theme_xkcd()
# Out:
# <ggplot: (286260889)>

# %%
ggplot(diamonds, aes(x='price')) + geom_histogram() + theme_538()
# Out:
# /Users/glamp/miniconda2/lib/python2.7/site-packages/ggplot-0.9.0-py2.7.egg/ggplot/ggplot.py:179: RuntimeWarning: Setting "mpl.rcParams['examples.download']=True" raised an Exception: u'examples.download is not a valid rc parameter.See rcParams.keys() for a list of valid parameters.'
#   warnings.warn(msg, RuntimeWarning)
# /Users/glamp/miniconda2/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: svg.embed_char_paths is deprecated and replaced with svg.fonttype; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# <ggplot: (285037533)>
